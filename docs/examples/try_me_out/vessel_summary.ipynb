# %% [markdown]
# ### Try out the VortexaSDK

# %% [markdown]
# First let's import our requirements

# %%
import vortexasdk as v

# %% [markdown]
# You'll need to enter your Vortexa API key when prompted.

# %%
# Let's load some vessel summaries for vessels with class "lng"
vesselSummaries = v.VesselSummary().search(vessel_class="lng").to_df()

# %%
vesselSummaries.head()

# %% [markdown]
# That's it! You've successfully loaded vessel summary data using the Vortexa SDK. Check out https://vortechsa.github.io/python-sdk/ for more examples
