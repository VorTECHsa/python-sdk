# %% [markdown]
# ### This notebook gives a 30 second introduction to the Vortexa SDK

# %% [markdown]
# First let's import our requirements

# %%
from datetime import datetime
import vortexasdk as v

# %% [markdown]
# Now let's load a dataframe of vessel movements that loaded at the start of August, 2017.

# %% [markdown]
# You'll need to enter your Vortexa API key when prompted.

# %%
df = v.VesselMovements()\
    .search(filter_activity='loading_state',
        filter_time_min=datetime(2017, 8, 1),
        filter_time_max=datetime(2017, 8, 2))\
    .to_df()
# Out:
# Loading from API: 1000it [00:02, 374.55it/s]

# %%
df.head()
# Out:
#     vessel.name  vessel.imo  vessel.mmsi  vessel.cubic_capacity  vessel.dwt  \
# 0        A STAR   9159816.0    626074000                   9716       11047
# 1          AC-D   9428437.0    256934000                   8396        7842
# 2     ACHILLEAS   9398072.0    636014701                 333364      297950
# 3  AEGEAN ANGEL   9290323.0    240213000                 170784      159092
# 4   AEGEAN WAVE   9387920.0    477547300                  53502       49999
#
#   vessel.vessel_class     origin.location.port.label  \
# 0     general_purpose                    Haldia [IN]
# 1         tiny_tanker                   Temryuk [RU]
# 2           vlcc_plus             Jose Terminal [VE]
# 3             suezmax                Saint Rose [US]
# 4            handymax  Coatzacoalcos, Pajaritos [MX]
#
#    origin.location.sts_zone.label  origin.from_vessel.label  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
#
#    origin.to_vessel.label  ... destination.from_vessel.label  \
# 0                     NaN  ...                           NaN
# 1                     NaN  ...                           NaN
# 2                     NaN  ...                           NaN
# 3                     NaN  ...                       AUGUSTA
# 4                     NaN  ...                           NaN
#
#   destination.to_vessel.label    origin.start_timestamp  \
# 0                         NaN 2017-08-01 10:22:28+00:00
# 1                         NaN 2017-08-01 21:16:50+00:00
# 2                         NaN 2017-07-29 22:37:39+00:00
# 3                AEGEAN ANGEL 2017-07-31 07:28:08+00:00
# 4                         NaN 2017-07-31 21:25:48+00:00
#
#   destination.end_timestamp cargoes.0.product.group.label  \
# 0 2017-08-09 12:06:49+00:00      Dirty Petroleum Products
# 1 2017-08-19 12:15:38+00:00      Clean Petroleum Products
# 2 2017-09-26 01:20:06+00:00             Crude/Condensates
# 3 2017-08-09 14:57:11+00:00      Dirty Petroleum Products
# 4 2017-09-03 06:08:09+00:00      Clean Petroleum Products
#
#   cargoes.0.product.grade.label cargoes.0.product.grade.probability  \
# 0                 Bitumen 60/70                            1.000000
# 1                           NaN                                 NaN
# 2                         Merey                            0.999948
# 3                           NaN                                 NaN
# 4                Cactus Naphtha                            1.000000
#
#   vessel.corporate_entities.charterer.label  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                               PHILLIPS 66
# 4                                        BP
#
#    vessel.corporate_entities.time_charterer.label  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   vessel.corporate_entities.commercial_owner.label
# 0                                          UNKNOWN
# 1                                              NaN
# 2                                           CURZON
# 3                                          ARCADIA
# 4                                     Norient Pool
#
# [5 rows x 22 columns]

# %% [markdown]
# That's it! You've successfully loaded data using the Vortexa SDK. Check out https://vortechsa.github.io/python-sdk/ for more examples
